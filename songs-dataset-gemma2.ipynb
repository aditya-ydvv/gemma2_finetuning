# %% [markdown]
# ## Step 1: Install Required Packages
# The following cell installs necessary Python packages for transliteration and text processing.

# %% [markdown]
# ### Step 1: Install Required Packages
# This step installs the necessary libraries like `indic-transliteration` for text processing in various Indian scripts.

# %%
# !pip install indic-transliteration
# Out:
# Collecting indic-transliteration
#   Downloading indic_transliteration-2.3.68-py3-none-any.whl.metadata (1.4 kB)
# Collecting backports.functools-lru-cache (from indic-transliteration)
#   Downloading backports.functools_lru_cache-2.0.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: regex in /opt/conda/lib/python3.10/site-packages (from indic-transliteration) (2024.5.15)
# Requirement already satisfied: typer in /opt/conda/lib/python3.10/site-packages (from indic-transliteration) (0.12.3)
# Requirement already satisfied: toml in /opt/conda/lib/python3.10/site-packages (from indic-transliteration) (0.10.2)
# Collecting roman (from indic-transliteration)
#   Downloading roman-4.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: click>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from typer->indic-transliteration) (8.1.7)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from typer->indic-transliteration) (4.12.2)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer->indic-transliteration) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/conda/lib/python3.10/site-packages (from typer->indic-transliteration) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer->indic-transliteration) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer->indic-transliteration) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->indic-transliteration) (0.1.2)
# Downloading indic_transliteration-2.3.68-py3-none-any.whl (155 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 4.1 MB/s eta 0:00:00
# Downloading backports.functools_lru_cache-2.0.0-py2.py3-none-any.whl (6.7 kB)
# Downloading roman-4.2-py3-none-any.whl (5.5 kB)
# Installing collected packages: roman, backports.functools-lru-cache, indic-transliteration
# Successfully installed backports.functools-lru-cache-2.0.0 indic-transliteration-2.3.68 roman-4.2

# %% [markdown]
# ## Step 2: Import Libraries
# In this step, we import essential libraries, including modules for transliteration, text processing, and data handling.

# %%
import json
import os
import requests
import re
import nltk

from itertools import islice
from collections import Counter, defaultdict
from concurrent.futures import ThreadPoolExecutor, as_completed
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate
from nltk.corpus import words

# %% [markdown]
# ## Step 3: Download NLTK Resources
# We download the NLTK words dataset, which will be useful for text processing tasks.

# %%
# Download nltk words list if not already downloaded
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to /usr/share/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
# Dictionary to hold the song data
lib_songs = {}

# Loop through the files in the directory
for dirname, _, filenames in os.walk('/kaggle/input/my-apple-music-library'):
    for filename in filenames:
        if filename.startswith('lib_songs_v') and filename.endswith('.json'):
            # Extract version number
            version = filename.split('_')[-1].split('.')[0]
            # Load the JSON file
            with open(os.path.join(dirname, filename), 'r') as f:
                lib_songs[f'lib_songs_{version}'] = json.load(f)

# Now lib_songs['lib_songs_v1'], lib_songs['lib_songs_v2'], etc. will contain the respective data

# %%
print("lib_songs: ",lib_songs.keys())
print("lib_songs_v2: ",lib_songs['lib_songs_v2'].keys())
print("resources: ",lib_songs['lib_songs_v2']['resources'].keys())
print("songs: ",list(islice(lib_songs['lib_songs_v2']['resources']['library-songs'].keys(), 5)))
print("song detail: ", lib_songs['lib_songs_v2']['resources']['library-songs']['i.V7Bv4lehZzk93Xq'].keys())
print("song attribute: ", lib_songs['lib_songs_v2']['resources']['library-songs']['i.V7Bv4lehZzk93Xq']['attributes'].keys())
# Out:
# lib_songs:  dict_keys(['lib_songs_v2', 'lib_songs_v1', 'lib_songs_v5', 'lib_songs_v3', 'lib_songs_v4'])
# lib_songs_v2:  dict_keys(['next', 'data', 'resources', 'meta'])
# resources:  dict_keys(['library-songs', 'songs'])
# songs:  ['i.V7Bv4lehZzk93Xq', 'i.LVk62JgSlGqNpYM', 'i.O1RGKbrHVxWpzrY', 'i.LVk6oXLtlGqNpYM', 'i.6xpNNGNtva0B5dE']
# song detail:  dict_keys(['id', 'type', 'href', 'attributes', 'relationships'])
# song attribute:  dict_keys(['discNumber', 'albumName', 'genreNames', 'hasLyrics', 'trackNumber', 'releaseDate', 'durationInMillis', 'name', 'artistName', 'artwork', 'playParams'])

# %%
# List of attributes to extract
extracted_attributes = ["albumName", "genreNames", "hasLyrics", "releaseDate", "durationInMillis", "name", "artistName"]

# Dictionary to store extracted attributes for each lib_songs_v file
extracted_data = {}

# Loop through all the files in the lib_songs dictionary
for lib_song_version, data in lib_songs.items():
    # Initialize a list to store the extracted attributes for the current version
    extracted_data[lib_song_version] = []
    
    # Access the 'library-songs' dictionary in each version
    library_songs = data['resources']['library-songs']
    
    # Loop through each song in the 'library-songs' dictionary
    for song_id, song_data in library_songs.items():
        # Access the 'attributes' for the current song
        attributes = song_data.get('attributes', {})
        
        # Extract only the required attributes
        extracted_song = {attr: attributes.get(attr) for attr in extracted_attributes}
        
        # Add the extracted song data to the list
        extracted_data[lib_song_version].append(extracted_song)

# %%
print(extracted_data.keys())
# Out:
# dict_keys(['lib_songs_v2', 'lib_songs_v1', 'lib_songs_v5', 'lib_songs_v3', 'lib_songs_v4'])

# %%
# Initialize a counter for the total number of songs
total_songs = 0

# Loop through the extracted data to count songs
for lib_song_version, songs in extracted_data.items():
    total_songs += len(songs)

# Display the total count of songs
print(f"Total number of songs: {total_songs}")
# Out:
# Total number of songs: 441

# %%
# Initialize a list to collect all genre names
all_genres = []

# Loop through the extracted data to collect genre names
for lib_song_version, songs in extracted_data.items():
    for song in songs:
        genres = song.get("genreNames", [])
        if genres:
            # Add genres to the list (some songs may have multiple genres)
            all_genres.extend(genres)

# Count the occurrence of each genre
genre_counts = Counter(all_genres)

# Display the top 10 most common genres
print("Top 10 most common genres:")
print(genre_counts.most_common(10))
# Out:
# Top 10 most common genres:
# [('Indian Pop', 80), ('Hip-Hop/Rap', 78), ('Bollywood', 65), ('Regional Indian', 46), ('Pop', 36), ('Worldwide', 29), ('Punjabi Pop', 29), ('Dance', 11), ('Indie Pop', 11), ('Punjabi', 10)]

# %%
unique_genres = set(all_genres)
print(f"Number of unique genres: {len(unique_genres)}")
print("Unique genres:", unique_genres)
# Out:
# Number of unique genres: 24
# Unique genres: {'', 'Electronic', 'Indian Pop', 'New Age', 'R&B/Soul', 'Dance', 'Hip-Hop', 'Haryanvi', 'Indie Pop', 'Soundtrack', 'Regional Indian', 'Asia', 'Comedy', 'Bollywood', 'Punjabi', 'House', 'Indian', 'Afrobeats', 'Worldwide', 'Hip-Hop/Rap', 'Pop', 'Rap', 'Singer/Songwriter', 'Punjabi Pop'}

# %%
# Dictionary to hold songs by genre
songs_by_genre = defaultdict(list)

# Loop through the extracted data to collect songs by genre
for lib_song_version, songs in extracted_data.items():
    for song in songs:
        genres = song.get("genreNames", [])
        song_name = song.get("name", "Unknown")
        artist_name = song.get("artistName", "Unknown Artist")
        release_date = song.get("releaseDate", "0000-00-00")  # Set a default for missing dates
        
        # Add each song to its respective genres
        for genre in genres:
            songs_by_genre[genre].append({
                'song_name': song_name,
                'artist_name': artist_name,
                'release_date': release_date
            })

# Function to display the top 10 songs in each genre
def display_top_songs_by_genre(songs_by_genre):
    for genre, songs in songs_by_genre.items():
        # Sort songs by release date, but handle cases where the date might be invalid
#         sorted_songs = sorted(songs, key=lambda x: x['release_date'] if x['release_date'] != "Unknown" else "0000-00-00", reverse=True)
        
        print(f"\nTop 10 songs in genre: {genre}")
        for i, song in enumerate(songs[:10], start=1):
            print(f"{i}. {song['song_name']} by {song['artist_name']} (Released: {song['release_date']})")

# Display top 10 songs for each genre
display_top_songs_by_genre(songs_by_genre)
# Out:
# Top 10 songs in genre: Indian Pop
# 1. Dj Waley Babu (feat. Aastha Gill) by Badshah (Released: 2015-07-17)
# 2. House of Lies by Ikka, Karan Aujla & Sanjoy (Released: 2024-05-18)
# 3. ILL.I.Am by Badshah (Released: 2018-08-17)
# 4. Driving Slow by Badshah (Released: 2016-08-17)
# 5. Ghar Jaane De by Mandys (Released: 2024-01-09)
# 6. Dream Boy by Babbal Rai (Released: 2017-06-29)
# 7. Hot Launde (feat. Fotty Seven & Bali) by Badshah (Released: 2020-08-07)
# 8. Gall Goriye by Raftaar & Maninder Buttar (Released: 2017-07-25)
# 9. Cyclone by UpsideDown & Jaz Dhami (Released: 2018-08-02)
# 10. Coco by Sukh-E Muzical Doctorz (Released: 2021-12-09)
#
# Top 10 songs in genre: Pop
# 1. Familiar by Liam Payne & J Balvin (Released: 2018-04-20)
# 2. Delilah by MIKOLAS & Mark Neve (Released: 2023-06-09)
# 3. Feel Hai by Bali & Badshah (Released: 2021-09-29)
# 4. Faasla (feat. Hasan Raheem) by Shamoon Ismail (Released: 2021-09-24)
# 5. God Damn by Badshah, Karan Aujla & Hiten (Released: 2024-03-18)
# 6. Dead Mangde by Navaan Sandhu (Released: 2023-01-27)
# 7. Hood Famous by Navaan Sandhu (Released: 2023-01-27)
# 8. Escapism. by RAYE & 070 Shake (Released: 2022-10-12)
# 9. Garage by Jass Manak & Avvy Sra (Released: 2024-04-10)
# 10. Daaku by Badshah & Sharvi Yadav (Released: 2024-03-18)
#
# Top 10 songs in genre: Hip-Hop/Rap
# 1. Hattrick (feat. Yaygo Musalini) by Imran Khan (Released: 2016-02-14)
# 2. Ha Ha Ha by Dhanda Nyoliwala & Deep Kalsi (Released: 2024-04-15)
# 3. Enjaay (feat. Sminil Agale, K. Shah & Kya.scene) by Chaar Diwaari (Released: 2022-08-26)
# 4. Drinks On Me by Badshah & MC Stan (Released: 2024-03-18)
# 5. Ichiban by Badshah (Released: 2023-02-07)
# 6. Imaginary by Imran Khan (Released: 2015-08-06)
# 7. Funk Song by Kidjaywest, Talwiinder & Ikath (Released: 2020-12-25)
# 8. ICE by Raftaar (Released: 2022-11-16)
# 9. Hola Amigo by KR$NA, Seedhe Maut & Umair (Released: 2023-08-28)
# 10. Hirni by Navaan Sandhu & Manjinder Sohi (Released: 2022-12-15)
#
# Top 10 songs in genre: Dance
# 1. Do It To It (feat. Cherish) by Acraze (Released: 2021-08-20)
# 2. Hey Mama (feat. Nicki Minaj, Bebe Rexha & Afrojack) by David Guetta (Released: 2014-11-21)
# 3. Dolly Song (Devil's Cup) by VIZE & Leony (Released: 2020-09-11)
# 4. Fast Cars & Superstars (feat. Reverend Haus) by Cristian Marchi (Released: 2023-12-22)
# 5. Bombay Dreams (feat. Kavita Seth) by KSHMR & Lost Stories (Released: 2019-09-13)
# 6. Mamacita by Rarin (Released: 2024-08-09)
# 7. Jadi Buti (feat. Rashmeet Kaur) by Major Lazer & Nucleya (Released: 2020-10-20)
# 8. Like A Snake by Badshah, Raftaar & Aastha Gill (Released: 2024-03-18)
# 9. Red And Blue by Badshah & SHAI (Released: 2024-03-18)
# 10. Toca Toca (Radio Edit) by Fly Project (Released: 2013-09-18)
#
# Top 10 songs in genre: Worldwide
# 1. Gang (feat. Inderpal Moga) by Chani Nattan & Turner (Released: 2023-04-07)
# 2. Dum Dee Dum by Zack Knight & Jasmin Walia (Released: 2016-04-27)
# 3. Double Addi (feat. Dj Ice & 2 Nyce) by Mickey Singh & Amar Sandhu (Released: 2014-07-31)
# 4. Galtiyan by Zack Knight (Released: 2017-12-15)
# 5. Got It All by UpsideDown & The PropheC (Released: 2018-05-10)
# 6. Hold Me by Mickey Singh (Released: 2016-12-06)
# 7. Havana by Kamal Raja (Released: 2016-10-10)
# 8. I Am Urban Desi by DJ Samir (Released: 2020-12-15)
# 9. Fortuner by Vikram Sarkar, Manisha Sharma & Khushi Baliyan (Released: 2022-09-12)
# 10. Bada Saang (feat. Nandini Sharma) by Kulbir Ahlawat, Raj Mawer & Anjali 99 (Released: 2024-05-28)
#
# Top 10 songs in genre: Regional Indian
# 1. Crazy n Love by Mickey Singh & Jay Skilly (Released: 2023-04-25)
# 2. I'm Outside by Mickey Singh & Jay Skilly (Released: 2023-04-04)
# 3. Infinity by Mickey Singh & Jay Skilly (Released: 2023-04-25)
# 4. Hold Me by Mickey Singh & UpsideDown (Released: 2016-12-06)
# 5. CROWD by Mickey Singh (Released: 2020-07-16)
# 6. Cruise Control by Mickey Singh & Jay Skilly (Released: 2023-04-25)
# 7. In Love by Mickey Singh & Asim Azhar (Released: 2013-07-19)
# 8. Bol Na by Mickey Singh & Jay Skilly (Released: 2023-04-25)
# 9. Addi Mardi by Mickey Singh (Released: 2016-06-29)
# 10. Band Bottle by Mickey Singh & The PropheC (Released: 2016-06-29)
#
# Top 10 songs in genre: Bollywood
# 1. Dilliwaali Girlfriend by Pritam, Arijit Singh & Sunidhi Chauhan (Released: 2013-03-30)
# 2. Dekho Nashe Mein by Shaan, KK, Sunidhi Chauhan & Pritam (Released: 2008-01-25)
# 3. Emotional Fool by Sharib Toshi & Toshi Sabri (Released: 2014-06-16)
# 4. Doobey (From "Gehraiyaan") by OAFF, Savera, Lothika & Kausar Munir (Released: 2022-01-24)
# 5. Dance Basanti (From "Ungli") by Sachin-Jigar, Vishal Dadlani & Anushka Manchanda (Released: 2014-10-28)
# 6. Galat Baat Hai by Neeti Mohan & Javed Ali (Released: 2014-03-03)
# 7. Ishq Ka Kalma by Pritam & Neeraj Shridhar (Released: 2007-10-27)
# 8. Heart Throb by Pritam, Dev Negi & Amitabh Bhattacharya (Released: 2023-07-31)
# 9. Humraah by Sachet Tandon (Released: 2020-01-23)
# 10. Balam Pichkari by Pritam, Vishal Dadlani & Shalmali Kholgade (Released: 2013-03-30)
#
# Top 10 songs in genre: Indie Pop
# 1. Impossible by Zack Knight (Released: 2022-09-15)
# 2. Ariana by Zack Knight & Harman Kaur (Released: 2022-09-15)
# 3. Caliente by Zack Knight & Shen B (Released: 2022-09-15)
# 4. Bang by Zack Knight & Jasmin Walia (Released: 2022-09-15)
# 5. When Was The Last Time by Zack Knight & Sha Sha Jones (Released: 2022-09-15)
# 6. Massiah by Zack Knight (Released: 2022-09-15)
# 7. Love With You by Zack Knight (Released: 2022-09-15)
# 8. Kamlee by Zack Knight & Omer Nadeem (Released: 2022-09-15)
# 9. Tension by Zack Knight & Sama Blake (Released: 2022-09-15)
# 10. This is Haryana by Badal (Released: 2023-07-20)
#
# Top 10 songs in genre: Punjabi Pop
# 1. Come To Me by Deep Money & Badshah (Released: 2012-09-18)
# 2. Hail by Tarna & Byg Byrd (Released: 2023-01-06)
# 3. Harmonious by Pav Dharia (Released: 2017-12-03)
# 4. Half Window Down by Ikka, Dr Zeus & Neetu Singh (Released: 2016-01-13)
# 5. GODSPEED by Tyson Sidhu (Released: 2022-07-08)
# 6. Defaulter by R Nait & Gurlej Akhtar (Released: 2019-02-09)
# 7. Ik Tera by Maninder Buttar (Released: 2019-08-21)
# 8. Bottle by Deep Money & Raftaar (Released: 2012-09-18)
# 9. Bamb by Sukh-E Muzical Doctorz & Badshah (Released: 2018-07-18)
# 10. Billo (feat. Raxstar & Manav Sangha) by Pav Dharia (Released: 2019-12-13)
#
# Top 10 songs in genre: Rap
# 1. Galat Karam by Panther & Raga (Released: 2023-11-10)
# 2. Sitara by DIVINE & Jonita Gandhi (Released: 2022-11-10)
#
# Top 10 songs in genre: Punjabi
# 1. Gallan 4 by Talwiinder (Released: 2020-06-13)
# 2. Fully Loaded by Tegi Pannu & Manni Sandhu (Released: 2021-10-15)
# 3. Aukaat by J BOWRA (Released: 2022-05-04)
# 4. Attraction by Sukha & prodGK (Released: 2023-07-14)
# 5. Ykwim (feat. Mehar Vaani) by Karan Aujla & KR$NA (Released: 2022-01-18)
# 6. Lost by Tegi Pannu & Manni Sandhu (Released: 2024-04-05)
# 7. Raat Jashan Di by Yo Yo Honey Singh & Jasmine Sandlas (Released: 2016-04-06)
# 8. Superman by Yo Yo Honey Singh (Released: 2016-04-06)
# 9. Switchin' Lanes by Tegi Pannu, Sukha & Manni Sandhu (Released: 2023-05-26)
# 10. Police by DJ Flow (Released: 2020-02-29)
#
# Top 10 songs in genre: R&B/Soul
# 1. DJ Got Us Fallin' in Love (feat. Pitbull) by USHER (Released: 2010-07-12)
# 2. Go Crazy by Chris Brown & Young Thug (Released: 2020-05-05)
# 3. Go Crazy (Remix) [feat. Future, Lil Durk & Latto] by Chris Brown & Young Thug (Released: 2021-02-19)
# 4. Baby No Way by Addy Nagar (Released: 2022-01-17)
# 5. Can't Feel My Face by The Weeknd (Released: 2015-06-05)
# 6. Angel by Zack Knight (Released: 2019-08-26)
# 7. AMG by Badshah & Mehar Vaani (Released: 2024-03-18)
# 8. Batman by Aghor & KR$NA (Released: 2022-06-18)
# 9. Mi Amor by Sharn, 40K & THE Paul (Released: 2022-09-30)
# 10. Slide (Remix) [feat. Pop Smoke, A Boogie wit da Hoodie & Chris Brown] by H.E.R. (Released: 2020-01-17)
#
# Top 10 songs in genre: Indian
# 1. Dhoor by Ezu (Released: 2023-06-23)
# 2. Bandook by Badshah & Raxstar (Released: 2014-08-27)
# 3. Untitled by KR$NA (Released: 2020-01-27)
# 4. Na Ja by Pav Dharia (Released: 2017-02-20)
# 5. No Cap by KR$NA (Released: 2021-11-10)
# 6. Let's fight by Addy Nagar (Released: 2022-10-11)
# 7. SAKSHAM by Addy Nagar & Panther (Released: 2023-10-10)
# 8. Party All Night (From "Boss") by Yo Yo Honey Singh (Released: 2013-09-09)
# 9. Pom Pom by Ezu (Released: 2023-05-04)
#
# Top 10 songs in genre: Soundtrack
# 1. Cross Your Mind by Sabrina Claudio (Released: 2018-02-09)
# 2. Drama by Raftaar (Released: 2020-04-13)
# 3. Naina (From "Crew") by Diljit Dosanjh, Badshah & Raj Ranjodh (Released: 2024-03-05)
# 4. Lamborghini by Rajat Nagpal & Jass Manak (Released: 2022-02-19)
# 5. Move by Raftaar (Released: 2020-03-23)
# 6. Tujhse by Mickey Singh (Released: 2016-03-08)
#
# Top 10 songs in genre: House
# 1. From 80s To 21 by KEAN DYSSO & BVLACLAVA (Released: 2020-10-30)
#
# Top 10 songs in genre: Singer/Songwriter
# 1. Gone Girl by Badshah & Payal Dev (Released: 2023-08-08)
#
# Top 10 songs in genre: Comedy
# 1. Chimney Vich 2.0 (feat. Mickey Singh) by Geeta Brothers Duet Group (Released: 2016-12-24)
#
# Top 10 songs in genre: New Age
# 1. Antidote by Karan Aujla (Released: 2024-06-26)
# 2. Y.D.G by Karan Aujla & Yeah Proof (Released: 2024-06-26)
# 3. Who They? by Karan Aujla & Yeah Proof (Released: 2024-06-26)
# 4. On Top 2 by Karan Aujla & Yeah Proof (Released: 2024-06-09)
#
# Top 10 songs in genre: Hip-Hop
# 1. 100 Million by DIVINE & Karan Aujla (Released: 2024-01-18)
# 2. Nothing Lasts by DIVINE & Karan Aujla (Released: 2024-02-16)
# 3. Straight Ballin' by DIVINE & Karan Aujla (Released: 2024-02-16)
# 4. Top Class / Overseas by DIVINE & Karan Aujla (Released: 2024-02-16)
#
# Top 10 songs in genre: Asia
# 1. Kina Chir by The PropheC (Released: 2016-12-29)
# 2. Naina (feat. Mickey Singh & DJ Hark) by The PropheC (Released: 2016-09-08)
# 3. Ki Kargeyi (feat. The PropheC) by Raxstar (Released: 2018-09-01)
# 4. Patakay (feat. Amar Sandhu & Ezu) by DJ Harpz (Released: 2018-09-13)
#
# Top 10 songs in genre: Electronic
# 1. Mirza (feat. Rashmeet Kaur & Raftaar) by Nucleya (Released: 2018-10-15)
#
# Top 10 songs in genre: Haryanvi
# 1. No Mercy by Dhanda Nyoliwala & Desi Melbourniye (Released: 2023-02-16)
#
# Top 10 songs in genre: Afrobeats
# 1. Ta Ta Ta (with Jason Derulo) by Bayanni & Jason Derulo (Released: 2023-04-14)
#
# Top 10 songs in genre:
# 1. Panamera White - RiskyjaTT.CoM by Diljit Dosanjh - RiskyjaTT.CoM (Released: None)

# %%
# List to store songs with lyrics
songs_with_lyrics = []

# Loop through the extracted data to find songs with lyrics
for lib_song_version, songs in extracted_data.items():
    for song in songs:
        if song.get("hasLyrics", False):  # Check if the song has lyrics
            song_name = song.get("name", "Unknown")
            artist_name = song.get("artistName", "Unknown Artist")
            
            # Add the song to the list
            songs_with_lyrics.append({
                'song_name': song_name,
                'artist_name': artist_name,
                'lyrics': ""
            })

# Display the songs that have lyrics
print(f"Total songs with lyrics: {len(songs_with_lyrics)}")
for song in songs_with_lyrics:
    print(f"{song['song_name']} by {song['artist_name']}")
    
# # Define the path where you want to save the JSON file
# output_file_path = 'songs_with_lyrics.json'

# # Save the songs with lyrics to a JSON file
# with open(output_file_path, 'w', encoding='utf-8') as json_file:
#     json.dump(songs_with_lyrics, json_file, ensure_ascii=False, indent=4)

# print(f"Songs with lyrics saved to {output_file_path}.")
# Out:
# Total songs with lyrics: 311
# Dj Waley Babu (feat. Aastha Gill) by Badshah
# Familiar by Liam Payne & J Balvin
# Hattrick (feat. Yaygo Musalini) by Imran Khan
# Do It To It (feat. Cherish) by Acraze
# ILL.I.Am by Badshah
# Driving Slow by Badshah
# Delilah by MIKOLAS & Mark Neve
# Feel Hai by Bali & Badshah
# Enjaay (feat. Sminil Agale, K. Shah & Kya.scene) by Chaar Diwaari
# Crazy n Love by Mickey Singh & Jay Skilly
# Impossible by Zack Knight
# Drinks On Me by Badshah & MC Stan
# Ichiban by Badshah
# Double Addi (feat. Dj Ice & 2 Nyce) by Mickey Singh & Amar Sandhu
# Faasla (feat. Hasan Raheem) by Shamoon Ismail
# Ghar Jaane De by Mandys
# I'm Outside by Mickey Singh & Jay Skilly
# Galtiyan by Zack Knight
# Dekho Nashe Mein by Shaan, KK, Sunidhi Chauhan & Pritam
# Imaginary by Imran Khan
# God Damn by Badshah, Karan Aujla & Hiten
# Funk Song by Kidjaywest, Talwiinder & Ikath
# Got It All by UpsideDown & The PropheC
# Dream Boy by Babbal Rai
# Hot Launde (feat. Fotty Seven & Bali) by Badshah
# Gall Goriye by Raftaar & Maninder Buttar
# Hey Mama (feat. Nicki Minaj, Bebe Rexha & Afrojack) by David Guetta
# Cyclone by UpsideDown & Jaz Dhami
# Harmonious by Pav Dharia
# Galat Karam by Panther & Raga
# Infinity by Mickey Singh & Jay Skilly
# Coco by Sukh-E Muzical Doctorz
# Galat Hogeya by Rishi Rich, Sukriti Kakar & Mumzy Stranger
# Emotional Fool by Sharib Toshi & Toshi Sabri
# Getup Jawani by Badshah & Yo Yo Honey Singh
# ICE by Raftaar
# Dolly Song (Devil's Cup) by VIZE & Leony
# Eyes On You (Radio Mix) by Jay Sean
# Gallan 4 by Talwiinder
# Hold Me by Mickey Singh
# Doobey (From "Gehraiyaan") by OAFF, Savera, Lothika & Kausar Munir
# Escapism. by RAYE & 070 Shake
# Famous by Arjun Kanungo
# Dance Basanti (From "Ungli") by Sachin-Jigar, Vishal Dadlani & Anushka Manchanda
# Interstellar by Badshah
# DJ Got Us Fallin' in Love (feat. Pitbull) by USHER
# Come Through by Bankrol Hayden & Lil Tecca
# Half Window Down by Ikka, Dr Zeus & Neetu Singh
# Go Crazy by Chris Brown & Young Thug
# Havana by Kamal Raja
# Fast Cars & Superstars (feat. Reverend Haus) by Cristian Marchi
# Hold Me by Mickey Singh & UpsideDown
# Gangsta (feat. YG) by Karan Aujla
# Fall Off (Interlude) by KR$NA
# FML by Arizona Zervas
# Hass Hass by Diljit Dosanjh, Sia & Greg Kurstin
# Fast Cars by Badshah
# GODSPEED by Tyson Sidhu
# Feels Like by Mickey Singh & Jess Loco
# Cross Your Mind by Sabrina Claudio
# F16 by Raftaar
# Go Crazy (Remix) [feat. Future, Lil Durk & Latto] by Chris Brown & Young Thug
# CROWD by Mickey Singh
# Ishq Ka Raja by Addy Nagar & Hamsar Hayat
# Gone Girl by Badshah & Payal Dev
# Heart Throb by Pritam, Dev Negi & Amitabh Bhattacharya
# Garage by Jass Manak & Avvy Sra
# Drama by Raftaar
# Cruise Control by Mickey Singh & Jay Skilly
# Ghana Kasoota (feat. Surbhi Jyoti) by Raftaar & Rashmeet Kaur
# Gur Nalon Ishq Mitha by Monali Thakur & Mickey Singh
# Fully Loaded by Tegi Pannu & Manni Sandhu
# Hola At Your Boy by Badshah, KR$NA & Prajina
# Defaulter by R Nait & Gurlej Akhtar
# Ik Tera by Maninder Buttar
# Daaku by Badshah & Sharvi Yadav
# Dhundhala by Yashraj, Dropped Out & Talwiinder
# Bol Na by Mickey Singh & Jay Skilly
# Bad for Me (feat. Stunnah Beatz) by Chitralekha Sen, Mickey Singh & Shah Rule
# Boht Tej by Badshah & Fotty Seven
# Are You With Me by Mickey Singh & Jay Skilly
# Body (feat. Sunny Brown & Fateh Doe) by Mickey Singh
# Backwards by Alexander Stewart
# Bombay Dreams (feat. Kavita Seth) by KSHMR & Lost Stories
# Another Love Song by Mickey Singh & 40K
# Admirin' You (feat. Preston Pablo) by Karan Aujla & Ikky
# Clout by Badshah
# Aadat Se Majboor by Ranveer Singh & Benny Dayal
# Ay Papi (feat. Rameet Sandhu) by Sama Blake
# Blowing Up by KR$NA
# Bitch by Dhanda Nyoliwala
# Alcoholic by Yo Yo Honey Singh
# Accounts by Nijjar & Yo Yo Honey Singh
# Awaara (feat. Reet Talwar) by Badshah
# Beat Pe Haley by Addy Nagar & Spoiler
# Beautiful by Millind Gaba
# Bachke Bachke (feat. Yarah) by Karan Aujla & Ikky
# Bang Bang by Benny Dayal & Neeti Mohan
# Aaja Soniye by Akash
# Afterhours by Bir, Dhanju & thiarajxtt
# Angaar (feat. Raftaar) by Ikka
# Baaki Baatein Peene Baad (Shots) [feat. Badshah] by Arjun Kanungo
# Aukaat by J BOWRA
# California Love by Cheema Y & Gur Sidhu
# Can't Feel My Face by The Weeknd
# Chingam Chabake by Vishal & Shekhar, Shankar Mahadevan & Shalmali Kholgade
# Angel by Zack Knight
# Black & White by Diljit Dosanjh
# Bkl by Badshah
# Aahun Aahun by Neeraj Shridhar, Master Saleem & Suzi Q
# Billionaire by Yo Yo Honey Singh, Simar Kaur & Singhsta
# Ayaashi by KK
# Baby Marvake Maanegi by Raftaar
# Celebrate by Mickey Singh & Jay Skilly
# Bandook by Badshah & Raxstar
# Ainvayi Ainvayi by Salim Merchant & Sunidhi Chauhan
# Bom Diggy by Zack Knight & Jasmin Walia
# Attraction by Sukha & prodGK
# Ayee by Harnoor, Jassa Dhillon & Ilam
# Black Suit by Mickey Singh
# Chora Baba Ka by Raftaar & Dhanda Nyoliwala
# Baliye Re (From "Jersey") by Sachet-Parampara, Sachet Tandon, Stebin Ben, Parampara Tandon & Mellow D
# Badmashi by Nagii, Addy Nagar & Sukhe Muzical Doctorz
# Billi Billi by Fazilpuria & Manisha Sharma
# Body Language (feat. THEMXXNLIGHT) by Ikka
# Aja Mahi (feat. Manjeet Singh, Mc Metz & MC Trix) by RDB
# Been a While (feat. Talha Anjum) by KR$NA
# Chaska by Krishna & Url
# Antidote by Karan Aujla
# Badan (feat. Harjas Harjaayi) by Raga
# Chamkeela Chehra by Badshah
# Bas by Jaz Dhami, Karan Aujla & Yeah Proof
# Asalaam-e-Ishqum by Bappi Lahiri & Neha Bhasin
# Batman by Aghor & KR$NA
# Billo (feat. Raxstar & Manav Sangha) by Pav Dharia
# Bombay To Punjab by Deep Jandu
# Wealth by Cheema Y & Gur Sidhu
# What's Up by KR$NA, Lisa Mishra & Rizzy Rico
# 36 by Raftaar
# Voodoo by Badshah, J Balvin & Tainy
# 100 Million by DIVINE & Karan Aujla
# 9:45 by Prabh Singh & Jay Trak
# Yaar Tu by Zack Knight
# Who's Heart by Mickey Singh & Jay Skilly
# We Don't Play by Sultaan, Jay Trak & Big Ghuman
# Untitled by KR$NA
# Wings by Mickey Singh & Jay Skilly
# 4 AM by Mickey Singh & Jonita Gandhi
# Yarri Yeah by Mickey Singh & Nani (Anjali)
# Y.D.G by Karan Aujla & Yeah Proof
# 4 Men Down by Millind Gaba
# Your Type (Tere Vargiyan) [feat. Mickey Singh] by Fateh
# Woh Raat by Raftaar & KR$NA
# White Brown Black by Avvy Sra & Karan Aujla
# 8 Parche (feat. Gur Sidhu) by Baani Sandhu
# Vele by Vishal & Shekhar, Shekhar Ravjiani & Vishal Dadlani
# Villain (feat. Karma & Ikka) by KR$NA
# 8 ASLE (feat. Gurlej Akhtar) by Sukha, Chani Nattan & prodGK
# Umbrella (feat. JAY-Z) by Rihanna
# Z Black by MD DesiRockstar
# YTL by Mickey Singh
# Wanna Know by KR$NA
# Wishes by Hasan Raheem, Umair & Talwiinder
# You by Jassa Dhillon & Mxrci
# Vibez by ZAYN
# Yaad Rakhna by Pav Dharia
# Ykwim (feat. Mehar Vaani) by Karan Aujla & KR$NA
# Who They? by Karan Aujla & Yeah Proof
# Vigdiyan Heeran by Yo Yo Honey Singh, Rony Ajnali & Gill Machhrai
# You by Karan Aujla & Ikky
# Winning Speech by Karan Aujla & MXRCI
# Kala Tikka (feat. Millind Gaba) by Gurnazar Chatha
# Lost by Tegi Pannu & Manni Sandhu
# Kina Chir by The PropheC
# Maiyya Mainu (From "Jersey") by Sachet-Parampara & Sachet Tandon
# Na Ja by Pav Dharia
# Mi Amor by Sharn, 40K & THE Paul
# Jhaag by Chaar Diwaari
# Knightridah by Imran Khan
# Lost by Mickey Singh
# Noor by Mickey Singh & Jay Skilly
# LA Girls by Charlie Puth
# Makhna by Tanishk Bagchi, Yasser Desai & Asees Kaur
# Nah They Can't by Prem Dhillon
# Let Me Be by Mickey Singh
# Lalkara (feat. Sultaan) by Diljit Dosanjh
# Jean Teri by Jaz Dhami, Raftaar & Deep Kalsi
# Mercy by Badshah
# Kand by Mickey Singh
# Mirza (feat. Rashmeet Kaur & Raftaar) by Nucleya
# Jatt Vailly by Diljit Dosanjh
# Mithi Mithi (feat. Jasmine Sandlas) by Amrit Maan
# Mamacita by Rarin
# Jee Ni Lagda by Karan Aujla & Ikky
# NO CHINA by Raftaar
# Manaka Da Munda by Jass Manak
# Jind Mahi by Diljit Dosanjh
# Kheench Maari by Raga, DG IMMORTALS & Nitin Randhawa
# Mahiya by Pav Dharia
# Jatta by Bunny Gill
# Naina (feat. Mickey Singh & DJ Hark) by The PropheC
# Kya by Neeraj Shridhar & Pritam
# Ki Lagda by Raka & Meavin
# Missing Me by Jess Loco & Mickey Singh
# Let's Celebrate by Imran Khan & Sonakshi Sinha
# Naina (From "Crew") by Diljit Dosanjh, Badshah & Raj Ranjodh
# Name On It (feat. Tedi Pagg) by Mickey Singh
# Jadi Buti (feat. Rashmeet Kaur) by Major Lazer & Nucleya
# No Mercy (Bonus Track) by Deep Kalsi, Raftaar, KR$NA & Karma
# Mexico by Karan Aujla
# Mera Saman Kahan Hai? by Chaar Diwaari
# Nashe Si Chadh Gayi by Vishal & Shekhar, Arijit Singh & Caralisa Monteiro
# Khayaal by Talwiinder & NDS
# Na Hai TIme by KR$NA
# Mascara by Cheema Y & Gur Sidhu
# No Reason by Parmish Verma & GD 47
# Kinni Kinni by Diljit Dosanjh
# Manma Emotion Jaage by Pritam, Amit Mishra, Anushka Manchanda & Antara Mitra
# Kiss Me Thru the Phone (feat. Sammie) by Soulja Boy Tell 'Em
# Move Your Body Now by Shaan, Hard Kaur, Suheil, Akriti Kakar & Pritam
# No Need by Karan Aujla
# Nadiyon Paar (Let the Music Play Again) by Sachin-Jigar, Rashmeet Kaur, Shamur & IP Singh
# Like A Snake by Badshah, Raftaar & Aastha Gill
# Kya Baat Ay by Harrdy Sandhu
# Mundeya Di Mautt by Raftaar & Yunan
# MOVE TO MIAMI (feat. Pitbull) by Enrique Iglesias
# Lucky No. 7 by Mankirt Aulakh & Baani Sandhu
# Ni Nachleh (feat. MC Spyder) by Imran Khan
# No Competition by Jass Manak
# Kaley Sheshe by Addy Nagar & Aniket Jain
# Joota Japani by KR$NA, Mukesh, Shankar - Jaikishan & Shailendra
# Kya Kehte Ho by Badshah
# Move by Raftaar
# Magic  Coke Studio Bharat (feat. thiarajxtt) by Diljit Dosanjh
# Mere Bina by KSHMR, The PropheC & Talha Anjum
# Lala Lori (feat. Afsana Khan) by Fazilpuria & Jaani
# Lucky Tu Lucky Me by Sachin-Jigar, Benny Dayal, Anushka Manchanda & Varun Dhawan
# Ki Kargeyi (feat. The PropheC) by Raxstar
# Jawani by Arjan Dhillon
# No Cap by KR$NA
# Koi Na by Badshah, Uchana Amit & Hiten
# Kamlee by Sarrb & Starboy X
# Kudiye by Pav Dharia
# Na Na by Mickey Singh & Jonita Gandhi
# Kala Chashma by Amar Arshi, Badshah, Neha Kakkar & Indeep Bakshi
# Nasha by Pav Dharia
# She Move It Like by Badshah
# Tujhse by Mickey Singh
# Sitara by DIVINE & Jonita Gandhi
# Sunn Na by Bali
# Role Model by KR$NA, Faris Shafi & Karma
# Ta Ta Ta (with Jason Derulo) by Bayanni & Jason Derulo
# Power by Addy Nagar & DRJ Sohail
# Summer Luv by Mickey Singh & Manpreet Toor
# Players (feat. Devika Badyal) by Badshah & Karan Aujla
# Take It Easy by Karan Aujla & Ikky
# Toca Toca (Radio Edit) by Fly Project
# Try Me by Karan Aujla & Ikky
# Touch Me by KK & Alisha Chinai
# On Top 2 by Karan Aujla & Yeah Proof
# Obsessed by Riar Saab & Abhijay Sharma
# Rewind (feat. Amar Sandhu) by Raxstar
# Sorry by Rajat Nagpal & Mickey Singh
# Notorious by Wazir Patar
# Thug Le by Vishal Dadlani & Shweta Pandit
# Tu Meri by Vishal Dadlani
# Patakay (feat. Amar Sandhu & Ezu) by DJ Harpz
# Rooftop Party (feat. Amar Sandhu) by Mickey Singh
# Rum Whisky by Akshay Verma
# Twist (Remix) by Neeraj Shridhar
# Punja Daab by DG IMMORTALS & Parmish Verma
# Spellbound by Dhanda Nyoliwala & Xvir Grewal
# Samne Rehni E by Pav Dharia
# Paisa Hai Toh by Sachin-Jigar, Vishal Dadlani, Mellow D & Jigar Saraiya
# Stay Away by KR$NA & Bharg
# Slide (Remix) [feat. Pop Smoke, A Boogie wit da Hoodie & Chris Brown] by H.E.R.
# Some Of Us by KR$NA & AR Paisley
# Priceless by Bhalwaan & Signature by SB
# Tabahi by Badshah
# Right Up There (feat. Lisa Mishra) by Badshah
# Take Your Sandals Off (feat. Badshah) by Girik Aman
# Roll Up (feat. Badshah) by KR$NA
# Switchin' Lanes by Tegi Pannu, Sukha & Manni Sandhu
# Pronto by Zack Knight
# Paagal by Badshah
# Rubicon Drill by Laddi Chahal, Parmish Verma & Gurlej Akhtar
# SPAIN by Jassa Dhillon & thiarajxtt
# Ooo La La by Rozei
# Snap (feat. Gurlez Akhtar) by Cheema Y & Gur Sidhu
# Showstopper by Jerry
# Nothing Lasts by DIVINE & Karan Aujla
# Police by DJ Flow
# Prarthana by KR$NA & Bharg
# Party On My Mind by KK, Shefali Alvares, Yo Yo Honey Singh, Pritam & Prashant Ingole
# Te Amo by Kamal Raja & AyoB
# Thrift Shop (feat. Wanz) by Macklemore & Ryan Lewis
# Phone by Mickey Singh & UpsideDown
# Shut Up by KR$NA & Subspace
# Paper Before Money by Navaan Sandhu
# Sift by Bhalwaan & Signature by SB
# System Pe System by R Maan
# Tauba Tauba (From "Bad Newz") by Karan Aujla
# Ptola by Mickey Singh & Pam Sengh
# Saiyaan by Pav Dharia
# Rain Over Me (feat. Marc Anthony) by Pitbull
# Straight Ballin' by DIVINE & Karan Aujla
# RAASHAH by Raftaar
# Rich Boy by payton
# Top Class / Overseas by DIVINE & Karan Aujla
# Still Standing by KR$NA
# Sheesha by Karan Aujla

# %%
# Musixmatch API key
MUSIXMATCH_API_KEY = 'your_api_key'

# Function to fetch lyrics using Musixmatch API
def fetch_lyrics_musixmatch(song):
    song_name = song['song_name']
    artist_name = song['artist_name']

    # Search for the song using Musixmatch API
    search_url = 'https://api.musixmatch.com/ws/1.1/track.search'
    params = {
        'q_track': song_name,
        'q_artist': artist_name,
        'page_size': 1,
        's_track_rating': 'desc',
        'apikey': MUSIXMATCH_API_KEY
    }

    response = requests.get(search_url, params=params)
    
    if response.status_code == 200:
        data = response.json()
        if data['message']['header']['status_code'] == 200 and data['message']['body']['track_list']:
            track_id = data['message']['body']['track_list'][0]['track']['track_id']

            # Get the lyrics for the found track
            lyrics_url = 'https://api.musixmatch.com/ws/1.1/track.lyrics.get'
            lyrics_params = {
                'track_id': track_id,
                'apikey': MUSIXMATCH_API_KEY
            }
            lyrics_response = requests.get(lyrics_url, params=lyrics_params)

            if lyrics_response.status_code == 200:
                lyrics_data = lyrics_response.json()
                if lyrics_data['message']['header']['status_code'] == 200:
                    lyrics = lyrics_data['message']['body']['lyrics']['lyrics_body']
                    lyrics = lyrics.replace("******* This Lyrics is NOT for Commercial use *******", "").strip()
                    return {
                        'song_name': song_name,
                        'artist_name': artist_name,
                        'lyrics': lyrics
                    }
    
    return {
        'song_name': song_name,
        'artist_name': artist_name,
        'lyrics': None
    }

# # Load the songs from the JSON file
# input_file_path = 'songs_with_lyrics.json'

# with open(input_file_path, 'r', encoding='utf-8') as json_file:
#     songs_with_lyrics = json.load(json_file)

# Filter for songs without lyrics
songs_without_lyrics = [song for song in songs_with_lyrics if song['lyrics'] == ""]

# Use ThreadPoolExecutor to fetch lyrics in parallel
with ThreadPoolExecutor(max_workers=10) as executor:
    future_to_song = {executor.submit(fetch_lyrics_musixmatch, song): song for song in songs_without_lyrics}
    
    for future in as_completed(future_to_song):
        song = future_to_song[future]
        try:
            result = future.result()
            if result['lyrics']:
                # Update the song with fetched lyrics
                for song_in_list in songs_with_lyrics:
                    if song_in_list['song_name'] == result['song_name'] and song_in_list['artist_name'] == result['artist_name']:
                        song_in_list['lyrics'] = result['lyrics']
                print(f"Lyrics found for {result['song_name']} by {result['artist_name']}")
                
#                 #Append the lyrics to the JSON file
#                 with open(input_file_path, 'w', encoding='utf-8') as json_file:
#                     json.dump(songs_with_lyrics, json_file, ensure_ascii=False, indent=4)
            else:
                print(f"Lyrics not found for {song['song_name']} by {song['artist_name']}")
        except Exception as e:
            print(f"Error fetching lyrics for {song['song_name']}: {e}")

# print(f"Updated songs with lyrics saved back to {input_file_path}.")
# Out:
# Lyrics not found for Hattrick (feat. Yaygo Musalini) by Imran Khan
# Lyrics found for Dj Waley Babu (feat. Aastha Gill) by Badshah
# Lyrics not found for Do It To It (feat. Cherish) by Acraze
# Lyrics found for Feel Hai by Bali & Badshah
# Lyrics found for Familiar by Liam Payne & J Balvin
# Lyrics found for Enjaay (feat. Sminil Agale, K. Shah & Kya.scene) by Chaar Diwaari
# Lyrics found for ILL.I.Am by Badshah
# Lyrics found for Driving Slow by Badshah
# Lyrics found for Crazy n Love by Mickey Singh & Jay Skilly
# Lyrics found for Delilah by MIKOLAS & Mark Neve
# Lyrics found for Impossible by Zack Knight
# Lyrics not found for Faasla (feat. Hasan Raheem) by Shamoon Ismail
# Lyrics not found for Ichiban by Badshah
# Lyrics found for Drinks On Me by Badshah & MC Stan
# Lyrics found for Imaginary by Imran Khan
# Lyrics found for I'm Outside by Mickey Singh & Jay Skilly
# Lyrics found for Double Addi (feat. Dj Ice & 2 Nyce) by Mickey Singh & Amar Sandhu
# Lyrics found for Galtiyan by Zack Knight
# Lyrics not found for Dekho Nashe Mein by Shaan, KK, Sunidhi Chauhan & Pritam
# Lyrics found for Ghar Jaane De by Mandys
# Lyrics found for God Damn by Badshah, Karan Aujla & Hiten
# Lyrics found for Funk Song by Kidjaywest, Talwiinder & Ikath
# Lyrics found for Galat Karam by Panther & Raga
# Lyrics found for Dream Boy by Babbal Rai
# Lyrics found for Hot Launde (feat. Fotty Seven & Bali) by Badshah
# Lyrics found for Got It All by UpsideDown & The PropheC
# Lyrics not found for Harmonious by Pav Dharia
# Lyrics found for Gall Goriye by Raftaar & Maninder Buttar
# Lyrics found for Cyclone by UpsideDown & Jaz Dhami
# Lyrics found for Hey Mama (feat. Nicki Minaj, Bebe Rexha & Afrojack) by David Guetta
# Lyrics found for Infinity by Mickey Singh & Jay Skilly
# Lyrics not found for Getup Jawani by Badshah & Yo Yo Honey Singh
# Lyrics found for Coco by Sukh-E Muzical Doctorz
# Lyrics not found for Galat Hogeya by Rishi Rich, Sukriti Kakar & Mumzy Stranger
# Lyrics found for ICE by Raftaar
# Lyrics found for Emotional Fool by Sharib Toshi & Toshi Sabri
# Lyrics found for Hold Me by Mickey Singh
# Lyrics found for Gallan 4 by Talwiinder
# Lyrics found for Dolly Song (Devil's Cup) by VIZE & Leony
# Lyrics found for Escapism. by RAYE & 070 Shake
# Lyrics found for Doobey (From "Gehraiyaan") by OAFF, Savera, Lothika & Kausar Munir
# Lyrics found for Eyes On You (Radio Mix) by Jay Sean
# Lyrics found for Famous by Arjun Kanungo
# Lyrics found for Dance Basanti (From "Ungli") by Sachin-Jigar, Vishal Dadlani & Anushka Manchanda
# Lyrics found for Come Through by Bankrol Hayden & Lil Tecca
# Lyrics not found for Fast Cars & Superstars (feat. Reverend Haus) by Cristian Marchi
# Lyrics not found for Gangsta (feat. YG) by Karan Aujla
# Lyrics found for Hold Me by Mickey Singh & UpsideDown
# Lyrics found for DJ Got Us Fallin' in Love (feat. Pitbull) by USHER
# Lyrics found for Interstellar by Badshah
# Lyrics found for Havana by Kamal Raja
# Lyrics found for Half Window Down by Ikka, Dr Zeus & Neetu Singh
# Lyrics found for Go Crazy by Chris Brown & Young Thug
# Lyrics found for Fall Off (Interlude) by KR$NA
# Lyrics found for FML by Arizona Zervas
# Lyrics found for GODSPEED by Tyson Sidhu
# Lyrics found for Hass Hass by Diljit Dosanjh, Sia & Greg Kurstin
# Lyrics found for CROWD by Mickey Singh
# Lyrics found for Fast Cars by Badshah
# Lyrics not found for Feels Like by Mickey Singh & Jess Loco
# Lyrics found for Go Crazy (Remix) [feat. Future, Lil Durk & Latto] by Chris Brown & Young Thug
# Lyrics found for Cross Your Mind by Sabrina Claudio
# Lyrics found for F16 by Raftaar
# Lyrics not found for Garage by Jass Manak & Avvy Sra
# Lyrics found for Ishq Ka Raja by Addy Nagar & Hamsar Hayat
# Lyrics found for Heart Throb by Pritam, Dev Negi & Amitabh Bhattacharya
# Lyrics found for Gone Girl by Badshah & Payal Dev
# Lyrics found for Ghana Kasoota (feat. Surbhi Jyoti) by Raftaar & Rashmeet Kaur
# Lyrics found for Hola At Your Boy by Badshah, KR$NA & Prajina
# Lyrics found for Gur Nalon Ishq Mitha by Monali Thakur & Mickey Singh
# Lyrics found for Fully Loaded by Tegi Pannu & Manni Sandhu
# Lyrics found for Drama by Raftaar
# Lyrics not found for Cruise Control by Mickey Singh & Jay Skilly
# Lyrics found for Defaulter by R Nait & Gurlej Akhtar
# Lyrics not found for Bad for Me (feat. Stunnah Beatz) by Chitralekha Sen, Mickey Singh & Shah Rule
# Lyrics not found for Body (feat. Sunny Brown & Fateh Doe) by Mickey Singh
# Lyrics found for Bol Na by Mickey Singh & Jay Skilly
# Lyrics found for Daaku by Badshah & Sharvi Yadav
# Lyrics found for Dhundhala by Yashraj, Dropped Out & Talwiinder
# Lyrics found for Boht Tej by Badshah & Fotty Seven
# Lyrics found for Ik Tera by Maninder Buttar
# Lyrics found for Backwards by Alexander Stewart
# Lyrics found for Are You With Me by Mickey Singh & Jay Skilly
# Lyrics found for Another Love Song by Mickey Singh & 40K
# Lyrics found for Bombay Dreams (feat. Kavita Seth) by KSHMR & Lost Stories
# Lyrics not found for Ay Papi (feat. Rameet Sandhu) by Sama Blake
# Lyrics found for Aadat Se Majboor by Ranveer Singh & Benny Dayal
# Lyrics found for Admirin' You (feat. Preston Pablo) by Karan Aujla & Ikky
# Lyrics found for Clout by Badshah
# Lyrics found for Alcoholic by Yo Yo Honey Singh
# Lyrics found for Accounts by Nijjar & Yo Yo Honey Singh
# Lyrics not found for Bitch by Dhanda Nyoliwala
# Lyrics found for Blowing Up by KR$NA
# Lyrics found for Awaara (feat. Reet Talwar) by Badshah
# Lyrics not found for Beat Pe Haley by Addy Nagar & Spoiler
# Lyrics found for Beautiful by Millind Gaba
# Lyrics found for Bachke Bachke (feat. Yarah) by Karan Aujla & Ikky
# Lyrics found for Angaar (feat. Raftaar) by Ikka
# Lyrics found for Aaja Soniye by Akash
# Lyrics found for Afterhours by Bir, Dhanju & thiarajxtt
# Lyrics found for Bang Bang by Benny Dayal & Neeti Mohan
# Lyrics found for California Love by Cheema Y & Gur Sidhu
# Lyrics found for Baaki Baatein Peene Baad (Shots) [feat. Badshah] by Arjun Kanungo
# Lyrics not found for Aukaat by J BOWRA
# Lyrics found for Angel by Zack Knight
# Lyrics found for Chingam Chabake by Vishal & Shekhar, Shankar Mahadevan & Shalmali Kholgade
# Lyrics found for Black & White by Diljit Dosanjh
# Lyrics found for Can't Feel My Face by The Weeknd
# Lyrics found for Billionaire by Yo Yo Honey Singh, Simar Kaur & Singhsta
# Lyrics found for Bkl by Badshah
# Lyrics found for Aahun Aahun by Neeraj Shridhar, Master Saleem & Suzi Q
# Lyrics found for Ayaashi by KK
# Lyrics found for Attraction by Sukha & prodGK
# Lyrics found for Baby Marvake Maanegi by Raftaar
# Lyrics found for Ainvayi Ainvayi by Salim Merchant & Sunidhi Chauhan
# Lyrics found for Celebrate by Mickey Singh & Jay Skilly
# Lyrics found for Bom Diggy by Zack Knight & Jasmin Walia
# Lyrics found for Bandook by Badshah & Raxstar
# Lyrics found for Ayee by Harnoor, Jassa Dhillon & Ilam
# Lyrics found for Black Suit by Mickey Singh
# Lyrics not found for Chora Baba Ka by Raftaar & Dhanda Nyoliwala
# Lyrics not found for Body Language (feat. THEMXXNLIGHT) by Ikka
# Lyrics not found for Been a While (feat. Talha Anjum) by KR$NA
# Lyrics not found for Aja Mahi (feat. Manjeet Singh, Mc Metz & MC Trix) by RDB
# Lyrics found for Baliye Re (From "Jersey") by Sachet-Parampara, Sachet Tandon, Stebin Ben, Parampara Tandon & Mellow D
# Lyrics not found for Billi Billi by Fazilpuria & Manisha Sharma
# Lyrics not found for Badmashi by Nagii, Addy Nagar & Sukhe Muzical Doctorz
# Lyrics found for Chaska by Krishna & Url
# Lyrics found for Antidote by Karan Aujla
# Lyrics not found for Badan (feat. Harjas Harjaayi) by Raga
# Lyrics found for Batman by Aghor & KR$NA
# Lyrics not found for Billo (feat. Raxstar & Manav Sangha) by Pav Dharia
# Lyrics found for Asalaam-e-Ishqum by Bappi Lahiri & Neha Bhasin
# Lyrics found for Chamkeela Chehra by Badshah
# Lyrics found for Bas by Jaz Dhami, Karan Aujla & Yeah Proof
# Lyrics not found for Wealth by Cheema Y & Gur Sidhu
# Lyrics found for Bombay To Punjab by Deep Jandu
# Lyrics not found for 36 by Raftaar
# Lyrics found for What's Up by KR$NA, Lisa Mishra & Rizzy Rico
# Lyrics found for Voodoo by Badshah, J Balvin & Tainy
# Lyrics found for 100 Million by DIVINE & Karan Aujla
# Lyrics found for 9:45 by Prabh Singh & Jay Trak
# Lyrics found for Yaar Tu by Zack Knight
# Lyrics found for Who's Heart by Mickey Singh & Jay Skilly
# Lyrics not found for We Don't Play by Sultaan, Jay Trak & Big Ghuman
# Lyrics found for Untitled by KR$NA
# Lyrics found for 4 AM by Mickey Singh & Jonita Gandhi
# Lyrics found for Wings by Mickey Singh & Jay Skilly
# Lyrics found for 4 Men Down by Millind Gaba
# Lyrics found for Yarri Yeah by Mickey Singh & Nani (Anjali)
# Lyrics found for Your Type (Tere Vargiyan) [feat. Mickey Singh] by Fateh
# Lyrics found for Woh Raat by Raftaar & KR$NA
# Lyrics found for Y.D.G by Karan Aujla & Yeah Proof
# Lyrics found for 8 Parche (feat. Gur Sidhu) by Baani Sandhu
# Lyrics not found for 8 ASLE (feat. Gurlej Akhtar) by Sukha, Chani Nattan & prodGK
# Lyrics found for Vele by Vishal & Shekhar, Shekhar Ravjiani & Vishal Dadlani
# Lyrics found for White Brown Black by Avvy Sra & Karan Aujla
# Lyrics found for Villain (feat. Karma & Ikka) by KR$NA
# Lyrics not found for Ykwim (feat. Mehar Vaani) by Karan Aujla & KR$NA
# Lyrics found for Wishes by Hasan Raheem, Umair & Talwiinder
# Lyrics not found for Z Black by MD DesiRockstar
# Lyrics found for Umbrella (feat. JAY-Z) by Rihanna
# Lyrics not found for YTL by Mickey Singh
# Lyrics found for Vibez by ZAYN
# Lyrics found for Wanna Know by KR$NA
# Lyrics found for Who They? by Karan Aujla & Yeah Proof
# Lyrics found for You by Jassa Dhillon & Mxrci
# Lyrics found for Yaad Rakhna by Pav Dharia
# Lyrics not found for Kala Tikka (feat. Millind Gaba) by Gurnazar Chatha
# Lyrics found for You by Karan Aujla & Ikky
# Lyrics found for Vigdiyan Heeran by Yo Yo Honey Singh, Rony Ajnali & Gill Machhrai
# Lyrics found for Maiyya Mainu (From "Jersey") by Sachet-Parampara & Sachet Tandon
# Lyrics found for Winning Speech by Karan Aujla & MXRCI
# Lyrics found for Na Ja by Pav Dharia
# Lyrics found for Kina Chir by The PropheC
# Lyrics found for Lost by Tegi Pannu & Manni Sandhu
# Lyrics found for Knightridah by Imran Khan
# Lyrics found for Jhaag by Chaar Diwaari
# Lyrics found for Mi Amor by Sharn, 40K & THE Paul
# Lyrics found for Lost by Mickey Singh
# Lyrics not found for Nah They Can't by Prem Dhillon
# Lyrics found for LA Girls by Charlie Puth
# Lyrics found for Let Me Be by Mickey Singh
# Lyrics found for Makhna by Tanishk Bagchi, Yasser Desai & Asees Kaur
# Lyrics found for Noor by Mickey Singh & Jay Skilly
# Lyrics not found for Mirza (feat. Rashmeet Kaur & Raftaar) by Nucleya
# Lyrics found for Lalkara (feat. Sultaan) by Diljit Dosanjh
# Lyrics found for Mercy by Badshah
# Lyrics not found for Mithi Mithi (feat. Jasmine Sandlas) by Amrit Maan
# Lyrics found for Kand by Mickey Singh
# Lyrics found for Mamacita by Rarin
# Lyrics found for Jatt Vailly by Diljit Dosanjh
# Lyrics found for Jean Teri by Jaz Dhami, Raftaar & Deep Kalsi
# Lyrics found for Jee Ni Lagda by Karan Aujla & Ikky
# Lyrics found for Jind Mahi by Diljit Dosanjh
# Lyrics found for NO CHINA by Raftaar
# Lyrics found for Manaka Da Munda by Jass Manak
# Lyrics found for Jatta by Bunny Gill
# Lyrics found for Mahiya by Pav Dharia
# Lyrics found for Missing Me by Jess Loco & Mickey Singh
# Lyrics found for Kheench Maari by Raga, DG IMMORTALS & Nitin Randhawa
# Lyrics found for Naina (feat. Mickey Singh & DJ Hark) by The PropheC
# Lyrics not found for Ki Lagda by Raka & Meavin
# Lyrics not found for Name On It (feat. Tedi Pagg) by Mickey Singh
# Lyrics found for Naina (From "Crew") by Diljit Dosanjh, Badshah & Raj Ranjodh
# Lyrics found for Kya by Neeraj Shridhar & Pritam
# Lyrics found for Jadi Buti (feat. Rashmeet Kaur) by Major Lazer & Nucleya
# Lyrics found for Mexico by Karan Aujla
# Lyrics found for Mera Saman Kahan Hai? by Chaar Diwaari
# Lyrics found for Khayaal by Talwiinder & NDS
# Lyrics found for Mascara by Cheema Y & Gur Sidhu
# Lyrics found for No Mercy (Bonus Track) by Deep Kalsi, Raftaar, KR$NA & Karma
# Lyrics found for Nashe Si Chadh Gayi by Vishal & Shekhar, Arijit Singh & Caralisa Monteiro
# Lyrics found for Let's Celebrate by Imran Khan & Sonakshi Sinha
# Lyrics found for No Reason by Parmish Verma & GD 47
# Lyrics found for Kinni Kinni by Diljit Dosanjh
# Lyrics found for Na Hai TIme by KR$NA
# Lyrics found for Kiss Me Thru the Phone (feat. Sammie) by Soulja Boy Tell 'Em
# Lyrics found for Manma Emotion Jaage by Pritam, Amit Mishra, Anushka Manchanda & Antara Mitra
# Lyrics found for Kya Baat Ay by Harrdy Sandhu
# Lyrics found for Like A Snake by Badshah, Raftaar & Aastha Gill
# Lyrics found for No Need by Karan Aujla
# Lyrics found for Mundeya Di Mautt by Raftaar & Yunan
# Lyrics not found for MOVE TO MIAMI (feat. Pitbull) by Enrique Iglesias
# Lyrics found for Nadiyon Paar (Let the Music Play Again) by Sachin-Jigar, Rashmeet Kaur, Shamur & IP Singh
# Lyrics found for Lucky No. 7 by Mankirt Aulakh & Baani Sandhu
# Lyrics found for Move Your Body Now by Shaan, Hard Kaur, Suheil, Akriti Kakar & Pritam
# Lyrics not found for Ni Nachleh (feat. MC Spyder) by Imran Khan
# Lyrics found for No Competition by Jass Manak
# Lyrics found for Kaley Sheshe by Addy Nagar & Aniket Jain
# Lyrics not found for Magic  Coke Studio Bharat (feat. thiarajxtt) by Diljit Dosanjh
# Lyrics found for Move by Raftaar
# Lyrics found for Joota Japani by KR$NA, Mukesh, Shankar - Jaikishan & Shailendra
# Lyrics found for Kya Kehte Ho by Badshah
# Lyrics not found for Ki Kargeyi (feat. The PropheC) by Raxstar
# Lyrics found for Lucky Tu Lucky Me by Sachin-Jigar, Benny Dayal, Anushka Manchanda & Varun Dhawan
# Lyrics found for Mere Bina by KSHMR, The PropheC & Talha Anjum
# Lyrics found for Lala Lori (feat. Afsana Khan) by Fazilpuria & Jaani
# Lyrics found for Jawani by Arjan Dhillon
# Lyrics found for Koi Na by Badshah, Uchana Amit & Hiten
# Lyrics not found for Kamlee by Sarrb & Starboy X
# Lyrics found for No Cap by KR$NA
# Lyrics found for She Move It Like by Badshah
# Lyrics found for Na Na by Mickey Singh & Jonita Gandhi
# Lyrics found for Kala Chashma by Amar Arshi, Badshah, Neha Kakkar & Indeep Bakshi
# Lyrics found for Tujhse by Mickey Singh
# Lyrics found for Sitara by DIVINE & Jonita Gandhi
# Lyrics found for Kudiye by Pav Dharia
# Lyrics found for Nasha by Pav Dharia
# Lyrics found for Sunn Na by Bali
# Lyrics not found for Power by Addy Nagar & DRJ Sohail
# Lyrics found for Role Model by KR$NA, Faris Shafi & Karma
# Lyrics found for Ta Ta Ta (with Jason Derulo) by Bayanni & Jason Derulo
# Lyrics found for Summer Luv by Mickey Singh & Manpreet Toor
# Lyrics found for Players (feat. Devika Badyal) by Badshah & Karan Aujla
# Lyrics found for Toca Toca (Radio Edit) by Fly Project
# Lyrics not found for Rewind (feat. Amar Sandhu) by Raxstar
# Lyrics found for Touch Me by KK & Alisha Chinai
# Lyrics found for Try Me by Karan Aujla & Ikky
# Lyrics found for Take It Easy by Karan Aujla & Ikky
# Lyrics found for On Top 2 by Karan Aujla & Yeah Proof
# Lyrics found for Sorry by Rajat Nagpal & Mickey Singh
# Lyrics found for Notorious by Wazir Patar
# Lyrics not found for Patakay (feat. Amar Sandhu & Ezu) by DJ Harpz
# Lyrics found for Obsessed by Riar Saab & Abhijay Sharma
# Lyrics found for Tu Meri by Vishal Dadlani
# Lyrics found for Rum Whisky by Akshay Verma
# Lyrics found for Thug Le by Vishal Dadlani & Shweta Pandit
# Lyrics found for Twist (Remix) by Neeraj Shridhar
# Lyrics found for Punja Daab by DG IMMORTALS & Parmish Verma
# Lyrics found for Rooftop Party (feat. Amar Sandhu) by Mickey Singh
# Lyrics found for Stay Away by KR$NA & Bharg
# Lyrics found for Samne Rehni E by Pav Dharia
# Lyrics found for Slide (Remix) [feat. Pop Smoke, A Boogie wit da Hoodie & Chris Brown] by H.E.R.
# Lyrics not found for Spellbound by Dhanda Nyoliwala & Xvir Grewal
# Lyrics found for Some Of Us by KR$NA & AR Paisley
# Lyrics found for Paisa Hai Toh by Sachin-Jigar, Vishal Dadlani, Mellow D & Jigar Saraiya
# Lyrics found for Take Your Sandals Off (feat. Badshah) by Girik Aman
# Lyrics found for Tabahi by Badshah
# Lyrics found for Roll Up (feat. Badshah) by KR$NA
# Lyrics found for Right Up There (feat. Lisa Mishra) by Badshah
# Lyrics not found for Priceless by Bhalwaan & Signature by SB
# Lyrics found for Switchin' Lanes by Tegi Pannu, Sukha & Manni Sandhu
# Lyrics not found for Pronto by Zack Knight
# Lyrics found for Paagal by Badshah
# Lyrics not found for Snap (feat. Gurlez Akhtar) by Cheema Y & Gur Sidhu
# Lyrics found for SPAIN by Jassa Dhillon & thiarajxtt
# Lyrics found for Rubicon Drill by Laddi Chahal, Parmish Verma & Gurlej Akhtar
# Lyrics found for Ooo La La by Rozei
# Lyrics found for Police by DJ Flow
# Lyrics found for Nothing Lasts by DIVINE & Karan Aujla
# Lyrics not found for Showstopper by Jerry
# Lyrics found for Prarthana by KR$NA & Bharg
# Lyrics found for Te Amo by Kamal Raja & AyoB
# Lyrics found for Thrift Shop (feat. Wanz) by Macklemore & Ryan Lewis
# Lyrics not found for Paper Before Money by Navaan Sandhu
# Lyrics found for Party On My Mind by KK, Shefali Alvares, Yo Yo Honey Singh, Pritam & Prashant Ingole
# Lyrics found for Phone by Mickey Singh & UpsideDown
# Lyrics not found for Shut Up by KR$NA & Subspace
# Lyrics found for Tauba Tauba (From "Bad Newz") by Karan Aujla
# Lyrics found for System Pe System by R Maan
# Lyrics found for Sift by Bhalwaan & Signature by SB
# Lyrics found for Rain Over Me (feat. Marc Anthony) by Pitbull
# Lyrics found for Ptola by Mickey Singh & Pam Sengh
# Lyrics found for Rich Boy by payton
# Lyrics found for Saiyaan by Pav Dharia
# Lyrics found for Straight Ballin' by DIVINE & Karan Aujla
# Lyrics found for RAASHAH by Raftaar
# Lyrics found for Top Class / Overseas by DIVINE & Karan Aujla
# Lyrics not found for Still Standing by KR$NA
# Lyrics found for Sheesha by Karan Aujla

# %%
# Load the songs from the JSON file
# input_file_path = '/kaggle/working/songs_with_lyrics.json'  # Replace with your file path

# with open(input_file_path, 'r', encoding='utf-8') as json_file:
#     songs_with_lyrics = json.load(json_file)

# Initialize counts
count_with_lyrics = 0
count_without_lyrics = 0

# Count songs with and without lyrics
for song in songs_with_lyrics:
    if song.get('lyrics'):
        count_with_lyrics += 1
    else:
        count_without_lyrics += 1

# Display the counts
print(f"Total songs with lyrics: {count_with_lyrics}")
print(f"Total songs without lyrics: {count_without_lyrics}")
# Out:
# Total songs with lyrics: 255
# Total songs without lyrics: 56

# %%
# Function to fetch lyrics using Lyrics.ovh API
def fetch_lyrics_ovh(song):
    song_name = song['song_name']
    artist_name = song['artist_name']
    url = f"https://api.lyrics.ovh/v1/{artist_name}/{song_name}"
    response = requests.get(url)
    
    if response.status_code == 200:
        lyrics = response.json().get('lyrics')
        return {
            'song_name': song_name,
            'artist_name': artist_name,
            'lyrics': lyrics
        }
    return {
        'song_name': song_name,
        'artist_name': artist_name,
        'lyrics': None
    }

# Load the songs from the JSON file
# input_file_path = '/kaggle/working/songs_with_lyrics.json'

# with open(input_file_path, 'r', encoding='utf-8') as json_file:
#     songs_with_lyrics = json.load(json_file)

# Filter for songs without lyrics
songs_without_lyrics = [song for song in songs_with_lyrics if song['lyrics'] == ""]

# Use ThreadPoolExecutor to fetch lyrics in parallel
with ThreadPoolExecutor(max_workers=10) as executor:
    # Create a future for each song
    future_to_song = {executor.submit(fetch_lyrics_ovh, song): song for song in songs_without_lyrics}
    
    # Process the results as they complete
    for future in as_completed(future_to_song):
        song = future_to_song[future]
        try:
            result = future.result()
            if result['lyrics']:
                # Update the song with fetched lyrics
                for song_in_list in songs_with_lyrics:
                    if song_in_list['song_name'] == result['song_name'] and song_in_list['artist_name'] == result['artist_name']:
                        song_in_list['lyrics'] = result['lyrics']
                print(f"Lyrics found for {result['song_name']} by {result['artist_name']}")
                
                # Append the lyrics to the JSON file
#                 with open(input_file_path, 'w', encoding='utf-8') as json_file:
#                     json.dump(songs_with_lyrics, json_file, ensure_ascii=False, indent=4)
                    
            else:
                print(f"Lyrics not found for {song['song_name']} by {song['artist_name']}")
        except Exception as e:
            print(f"Error fetching lyrics for {song['song_name']}: {e}")

# print(f"Updated songs with lyrics saved back to {input_file_path}.")
# Out:
# Lyrics found for Do It To It (feat. Cherish) by Acraze
# Lyrics not found for Hattrick (feat. Yaygo Musalini) by Imran Khan
# Lyrics not found for Ichiban by Badshah
# Lyrics not found for Harmonious by Pav Dharia
# Lyrics not found for Faasla (feat. Hasan Raheem) by Shamoon Ismail
# Lyrics not found for Getup Jawani by Badshah & Yo Yo Honey Singh
# Lyrics not found for Galat Hogeya by Rishi Rich, Sukriti Kakar & Mumzy Stranger
# Lyrics not found for Fast Cars & Superstars (feat. Reverend Haus) by Cristian Marchi
# Lyrics not found for Dekho Nashe Mein by Shaan, KK, Sunidhi Chauhan & Pritam
# Lyrics not found for Gangsta (feat. YG) by Karan Aujla
# Lyrics not found for Feels Like by Mickey Singh & Jess Loco
# Lyrics not found for Garage by Jass Manak & Avvy Sra
# Lyrics not found for Body (feat. Sunny Brown & Fateh Doe) by Mickey Singh
# Lyrics not found for Bitch by Dhanda Nyoliwala
# Lyrics not found for Ay Papi (feat. Rameet Sandhu) by Sama Blake
# Lyrics not found for Beat Pe Haley by Addy Nagar & Spoiler
# Lyrics not found for Bad for Me (feat. Stunnah Beatz) by Chitralekha Sen, Mickey Singh & Shah Rule
# Lyrics not found for Aukaat by J BOWRA
# Lyrics not found for Cruise Control by Mickey Singh & Jay Skilly
# Lyrics not found for Chora Baba Ka by Raftaar & Dhanda Nyoliwala
# Lyrics not found for Badmashi by Nagii, Addy Nagar & Sukhe Muzical Doctorz
# Lyrics not found for Billi Billi by Fazilpuria & Manisha Sharma
# Lyrics not found for Body Language (feat. THEMXXNLIGHT) by Ikka
# Lyrics not found for Aja Mahi (feat. Manjeet Singh, Mc Metz & MC Trix) by RDB
# Lyrics not found for Been a While (feat. Talha Anjum) by KR$NA
# Lyrics not found for Badan (feat. Harjas Harjaayi) by Raga
# Lyrics not found for Billo (feat. Raxstar & Manav Sangha) by Pav Dharia
# Lyrics not found for Wealth by Cheema Y & Gur Sidhu
# Lyrics not found for 36 by Raftaar
# Lyrics not found for We Don't Play by Sultaan, Jay Trak & Big Ghuman
# Lyrics not found for 8 ASLE (feat. Gurlej Akhtar) by Sukha, Chani Nattan & prodGK
# Lyrics found for MOVE TO MIAMI (feat. Pitbull) by Enrique Iglesias
# Lyrics not found for Z Black by MD DesiRockstar
# Lyrics not found for Kala Tikka (feat. Millind Gaba) by Gurnazar Chatha
# Lyrics not found for YTL by Mickey Singh
# Lyrics not found for Ykwim (feat. Mehar Vaani) by Karan Aujla & KR$NA
# Lyrics not found for Nah They Can't by Prem Dhillon
# Lyrics not found for Mithi Mithi (feat. Jasmine Sandlas) by Amrit Maan
# Lyrics not found for Mirza (feat. Rashmeet Kaur & Raftaar) by Nucleya
# Lyrics not found for Ki Lagda by Raka & Meavin
# Lyrics not found for Name On It (feat. Tedi Pagg) by Mickey Singh
# Lyrics not found for Ni Nachleh (feat. MC Spyder) by Imran Khan
# Lyrics not found for Magic  Coke Studio Bharat (feat. thiarajxtt) by Diljit Dosanjh
# Lyrics not found for Ki Kargeyi (feat. The PropheC) by Raxstar
# Lyrics not found for Kamlee by Sarrb & Starboy X
# Lyrics not found for Power by Addy Nagar & DRJ Sohail
# Lyrics not found for Rewind (feat. Amar Sandhu) by Raxstar
# Lyrics not found for Patakay (feat. Amar Sandhu & Ezu) by DJ Harpz
# Lyrics not found for Priceless by Bhalwaan & Signature by SB
# Lyrics not found for Spellbound by Dhanda Nyoliwala & Xvir Grewal
# Lyrics not found for Pronto by Zack Knight
# Lyrics not found for Snap (feat. Gurlez Akhtar) by Cheema Y & Gur Sidhu
# Lyrics not found for Showstopper by Jerry
# Lyrics not found for Shut Up by KR$NA & Subspace
# Lyrics not found for Paper Before Money by Navaan Sandhu
# Lyrics not found for Still Standing by KR$NA

# %%
# Load the songs from the JSON file
# input_file_path = '/kaggle/input/song-with-lyrics/songs_with_lyrics.json'  # Replace with your file path

# Load the English words dictionary from nltk
english_words_set = set(words.words())

# with open(input_file_path, 'r', encoding='utf-8') as json_file:
#     songs_with_lyrics = json.load(json_file)

# Regex patterns for Hindi, English, and expanded pattern to allow newlines and more punctuation
hindi_pattern = re.compile(r'[\u0900-\u097F]')
english_pattern = re.compile(r'[A-Za-z]')
# Allow Hindi, English, numbers, common punctuation, and newlines
allowed_pattern = re.compile(r'^[\u0900-\u097F A-Za-z0-9,.\'\"\-?!\s\n]+$')

# Function to check if lyrics contain more Hindi than English characters
def is_hindi_majority(lyrics):
    hindi_count = len(hindi_pattern.findall(lyrics))
    english_count = len(english_pattern.findall(lyrics))
    # Return True if there are more Hindi characters, or equal to ensure majority
    return hindi_count > english_count

# Function to check if lyrics contain only allowed characters (Hindi/English)
def contains_only_hindi_and_english(lyrics):
    return True
    return bool(allowed_pattern.match(lyrics))

# Function to convert Hinglish words to Hindi, leaving valid English words intact
def convert_hinglish_to_hindi_preserving_english(lyrics):
    words_in_lyrics = lyrics.split()  # Split lyrics into words
    converted_lyrics = []
    
    for word in words_in_lyrics:
        # Check if the word is a valid English word
        if is_valid_english_word(word):
            converted_lyrics.append(word)  # Keep the English word as it is
        else:
            # Attempt to transliterate the word (treat as Hinglish)
            try:
                converted_word = transliterate(word, sanscript.ITRANS, sanscript.DEVANAGARI)
                converted_lyrics.append(converted_word)
            except Exception as e:
                # If transliteration fails, keep the word as it is
                converted_lyrics.append(word)
    
    return ' '.join(converted_lyrics)  # Return the mixed converted lyrics

# Function to check if lyrics are in Hinglish based on valid English words and Hinglish patterns
def is_hinglish(lyrics):
    words_in_lyrics = lyrics.split()  # Split lyrics into words
    hinglish_count = 0
    english_count = 0
    
    for word in words_in_lyrics:
        # Check if the word is a valid English word
        if is_valid_english_word(word):
            english_count += 1
        elif english_pattern.search(word):
            # If it contains English alphabet characters but isn't a valid English word, count it as Hinglish
            hinglish_count += 1
    
    # If the majority of words are valid English, it's not Hinglish
    if english_count >= hinglish_count:
        return False  # Consider it as English
    else:
        return True  # Consider it as Hinglish


# Function to check if a word is a valid English word
def is_valid_english_word(word):
    return word.lower() in english_words_set

    
# List to store the selected songs
selected_songs = []

non_selected_songs = []

common_hinglish_patterns = [
    r"tum", r"mein", r"hai", r"hoon", r"ke", r"ka", r"ki", r"tha", r"nahi", r"kya", r"haath", r"dekh", r"pyaar", r"jao"
]

# Iterate over the songs and select those with Hindi-majority lyrics
for song in songs_with_lyrics:
    lyrics = song.get('lyrics')
    if lyrics:
        # Remove unwanted characters (optional, clean up if needed)
        clean_lyrics = lyrics.replace("******* This Lyrics is NOT for Commercial use *******", "").strip()
        
        if is_hindi_majority(clean_lyrics) and contains_only_hindi_and_english(clean_lyrics):
            selected_songs.append(song)
        elif is_hinglish(clean_lyrics):
            clean_lyrics = convert_hinglish_to_hindi_preserving_english(clean_lyrics)
            song['lyrics'] = clean_lyrics  # Update the song's lyrics with the converted Hindi text
            selected_songs.append(song)
        else:
            non_selected_songs.append(song)

# Display the count of selected songs and their details
print(f"Total songs with Hindi-majority lyrics: {len(selected_songs)}")
for song in selected_songs:
    print(f"{song['song_name']} by {song['artist_name']}")

# Display the count of non-selected songs and their details
print(f"\nTotal non-selected songs: {len(non_selected_songs)}")
for song in non_selected_songs:
    print(f"{song['song_name']} by {song['artist_name']}")
# Out:
# Total songs with Hindi-majority lyrics: 154
# Dj Waley Babu (feat. Aastha Gill) by Badshah
# ILL.I.Am by Badshah
# Driving Slow by Badshah
# Feel Hai by Bali & Badshah
# Enjaay (feat. Sminil Agale, K. Shah & Kya.scene) by Chaar Diwaari
# Crazy n Love by Mickey Singh & Jay Skilly
# Double Addi (feat. Dj Ice & 2 Nyce) by Mickey Singh & Amar Sandhu
# Ghar Jaane De by Mandys
# I'm Outside by Mickey Singh & Jay Skilly
# Funk Song by Kidjaywest, Talwiinder & Ikath
# Dream Boy by Babbal Rai
# Hot Launde (feat. Fotty Seven & Bali) by Badshah
# Gall Goriye by Raftaar & Maninder Buttar
# Galat Karam by Panther & Raga
# Coco by Sukh-E Muzical Doctorz
# Emotional Fool by Sharib Toshi & Toshi Sabri
# ICE by Raftaar
# Hold Me by Mickey Singh
# Doobey (From "Gehraiyaan") by OAFF, Savera, Lothika & Kausar Munir
# Famous by Arjun Kanungo
# Interstellar by Badshah
# Half Window Down by Ikka, Dr Zeus & Neetu Singh
# Hold Me by Mickey Singh & UpsideDown
# Fall Off (Interlude) by KR$NA
# Fast Cars by Badshah
# GODSPEED by Tyson Sidhu
# F16 by Raftaar
# Ishq Ka Raja by Addy Nagar & Hamsar Hayat
# Gone Girl by Badshah & Payal Dev
# Heart Throb by Pritam, Dev Negi & Amitabh Bhattacharya
# Drama by Raftaar
# Ghana Kasoota (feat. Surbhi Jyoti) by Raftaar & Rashmeet Kaur
# Gur Nalon Ishq Mitha by Monali Thakur & Mickey Singh
# Defaulter by R Nait & Gurlej Akhtar
# Ik Tera by Maninder Buttar
# Daaku by Badshah & Sharvi Yadav
# Dhundhala by Yashraj, Dropped Out & Talwiinder
# Bol Na by Mickey Singh & Jay Skilly
# Boht Tej by Badshah & Fotty Seven
# Another Love Song by Mickey Singh & 40K
# Admirin' You (feat. Preston Pablo) by Karan Aujla & Ikky
# Clout by Badshah
# Aadat Se Majboor by Ranveer Singh & Benny Dayal
# Blowing Up by KR$NA
# Awaara (feat. Reet Talwar) by Badshah
# Beautiful by Millind Gaba
# Bachke Bachke (feat. Yarah) by Karan Aujla & Ikky
# Bang Bang by Benny Dayal & Neeti Mohan
# Afterhours by Bir, Dhanju & thiarajxtt
# Angaar (feat. Raftaar) by Ikka
# Baaki Baatein Peene Baad (Shots) [feat. Badshah] by Arjun Kanungo
# California Love by Cheema Y & Gur Sidhu
# Chingam Chabake by Vishal & Shekhar, Shankar Mahadevan & Shalmali Kholgade
# Bkl by Badshah
# Aahun Aahun by Neeraj Shridhar, Master Saleem & Suzi Q
# Billionaire by Yo Yo Honey Singh, Simar Kaur & Singhsta
# Ayaashi by KK
# Baby Marvake Maanegi by Raftaar
# Bandook by Badshah & Raxstar
# Ainvayi Ainvayi by Salim Merchant & Sunidhi Chauhan
# Bom Diggy by Zack Knight & Jasmin Walia
# Ayee by Harnoor, Jassa Dhillon & Ilam
# Black Suit by Mickey Singh
# Baliye Re (From "Jersey") by Sachet-Parampara, Sachet Tandon, Stebin Ben, Parampara Tandon & Mellow D
# Chaska by Krishna & Url
# Antidote by Karan Aujla
# Chamkeela Chehra by Badshah
# Asalaam-e-Ishqum by Bappi Lahiri & Neha Bhasin
# Bombay To Punjab by Deep Jandu
# Voodoo by Badshah, J Balvin & Tainy
# 100 Million by DIVINE & Karan Aujla
# Who's Heart by Mickey Singh & Jay Skilly
# Untitled by KR$NA
# Yarri Yeah by Mickey Singh & Nani (Anjali)
# 4 Men Down by Millind Gaba
# Woh Raat by Raftaar & KR$NA
# White Brown Black by Avvy Sra & Karan Aujla
# Vele by Vishal & Shekhar, Shekhar Ravjiani & Vishal Dadlani
# Villain (feat. Karma & Ikka) by KR$NA
# Wishes by Hasan Raheem, Umair & Talwiinder
# Yaad Rakhna by Pav Dharia
# Who They? by Karan Aujla & Yeah Proof
# You by Karan Aujla & Ikky
# Maiyya Mainu (From "Jersey") by Sachet-Parampara & Sachet Tandon
# Jhaag by Chaar Diwaari
# Lost by Mickey Singh
# Noor by Mickey Singh & Jay Skilly
# Makhna by Tanishk Bagchi, Yasser Desai & Asees Kaur
# Jean Teri by Jaz Dhami, Raftaar & Deep Kalsi
# Mercy by Badshah
# Kand by Mickey Singh
# Jee Ni Lagda by Karan Aujla & Ikky
# NO CHINA by Raftaar
# Manaka Da Munda by Jass Manak
# Kheench Maari by Raga, DG IMMORTALS & Nitin Randhawa
# Naina (feat. Mickey Singh & DJ Hark) by The PropheC
# Kya by Neeraj Shridhar & Pritam
# Missing Me by Jess Loco & Mickey Singh
# Naina (From "Crew") by Diljit Dosanjh, Badshah & Raj Ranjodh
# Jadi Buti (feat. Rashmeet Kaur) by Major Lazer & Nucleya
# No Mercy (Bonus Track) by Deep Kalsi, Raftaar, KR$NA & Karma
# Mera Saman Kahan Hai? by Chaar Diwaari
# Nashe Si Chadh Gayi by Vishal & Shekhar, Arijit Singh & Caralisa Monteiro
# Khayaal by Talwiinder & NDS
# Na Hai TIme by KR$NA
# Mascara by Cheema Y & Gur Sidhu
# No Reason by Parmish Verma & GD 47
# Manma Emotion Jaage by Pritam, Amit Mishra, Anushka Manchanda & Antara Mitra
# Like A Snake by Badshah, Raftaar & Aastha Gill
# Mundeya Di Mautt by Raftaar & Yunan
# Lucky No. 7 by Mankirt Aulakh & Baani Sandhu
# Kaley Sheshe by Addy Nagar & Aniket Jain
# Joota Japani by KR$NA, Mukesh, Shankar - Jaikishan & Shailendra
# Kya Kehte Ho by Badshah
# Move by Raftaar
# Mere Bina by KSHMR, The PropheC & Talha Anjum
# Lala Lori (feat. Afsana Khan) by Fazilpuria & Jaani
# Lucky Tu Lucky Me by Sachin-Jigar, Benny Dayal, Anushka Manchanda & Varun Dhawan
# No Cap by KR$NA
# Koi Na by Badshah, Uchana Amit & Hiten
# Kudiye by Pav Dharia
# Na Na by Mickey Singh & Jonita Gandhi
# Kala Chashma by Amar Arshi, Badshah, Neha Kakkar & Indeep Bakshi
# Tujhse by Mickey Singh
# Sitara by DIVINE & Jonita Gandhi
# Sunn Na by Bali
# Role Model by KR$NA, Faris Shafi & Karma
# Summer Luv by Mickey Singh & Manpreet Toor
# Take It Easy by Karan Aujla & Ikky
# Toca Toca (Radio Edit) by Fly Project
# Try Me by Karan Aujla & Ikky
# Touch Me by KK & Alisha Chinai
# On Top 2 by Karan Aujla & Yeah Proof
# Obsessed by Riar Saab & Abhijay Sharma
# Thug Le by Vishal Dadlani & Shweta Pandit
# Tu Meri by Vishal Dadlani
# Punja Daab by DG IMMORTALS & Parmish Verma
# Paisa Hai Toh by Sachin-Jigar, Vishal Dadlani, Mellow D & Jigar Saraiya
# Tabahi by Badshah
# Take Your Sandals Off (feat. Badshah) by Girik Aman
# Roll Up (feat. Badshah) by KR$NA
# Paagal by Badshah
# Rubicon Drill by Laddi Chahal, Parmish Verma & Gurlej Akhtar
# SPAIN by Jassa Dhillon & thiarajxtt
# Nothing Lasts by DIVINE & Karan Aujla
# Prarthana by KR$NA & Bharg
# Party On My Mind by KK, Shefali Alvares, Yo Yo Honey Singh, Pritam & Prashant Ingole
# System Pe System by R Maan
# Tauba Tauba (From "Bad Newz") by Karan Aujla
# Ptola by Mickey Singh & Pam Sengh
# Saiyaan by Pav Dharia
# RAASHAH by Raftaar
# Top Class / Overseas by DIVINE & Karan Aujla
# Sheesha by Karan Aujla
#
# Total non-selected songs: 103
# Familiar by Liam Payne & J Balvin
# Do It To It (feat. Cherish) by Acraze
# Delilah by MIKOLAS & Mark Neve
# Impossible by Zack Knight
# Drinks On Me by Badshah & MC Stan
# Galtiyan by Zack Knight
# Imaginary by Imran Khan
# God Damn by Badshah, Karan Aujla & Hiten
# Got It All by UpsideDown & The PropheC
# Hey Mama (feat. Nicki Minaj, Bebe Rexha & Afrojack) by David Guetta
# Cyclone by UpsideDown & Jaz Dhami
# Infinity by Mickey Singh & Jay Skilly
# Dolly Song (Devil's Cup) by VIZE & Leony
# Eyes On You (Radio Mix) by Jay Sean
# Gallan 4 by Talwiinder
# Escapism. by RAYE & 070 Shake
# Dance Basanti (From "Ungli") by Sachin-Jigar, Vishal Dadlani & Anushka Manchanda
# DJ Got Us Fallin' in Love (feat. Pitbull) by USHER
# Come Through by Bankrol Hayden & Lil Tecca
# Go Crazy by Chris Brown & Young Thug
# Havana by Kamal Raja
# FML by Arizona Zervas
# Hass Hass by Diljit Dosanjh, Sia & Greg Kurstin
# Cross Your Mind by Sabrina Claudio
# Go Crazy (Remix) [feat. Future, Lil Durk & Latto] by Chris Brown & Young Thug
# CROWD by Mickey Singh
# Fully Loaded by Tegi Pannu & Manni Sandhu
# Hola At Your Boy by Badshah, KR$NA & Prajina
# Are You With Me by Mickey Singh & Jay Skilly
# Backwards by Alexander Stewart
# Bombay Dreams (feat. Kavita Seth) by KSHMR & Lost Stories
# Alcoholic by Yo Yo Honey Singh
# Accounts by Nijjar & Yo Yo Honey Singh
# Aaja Soniye by Akash
# Can't Feel My Face by The Weeknd
# Angel by Zack Knight
# Black & White by Diljit Dosanjh
# Celebrate by Mickey Singh & Jay Skilly
# Attraction by Sukha & prodGK
# Bas by Jaz Dhami, Karan Aujla & Yeah Proof
# Batman by Aghor & KR$NA
# What's Up by KR$NA, Lisa Mishra & Rizzy Rico
# 9:45 by Prabh Singh & Jay Trak
# Yaar Tu by Zack Knight
# Wings by Mickey Singh & Jay Skilly
# 4 AM by Mickey Singh & Jonita Gandhi
# Y.D.G by Karan Aujla & Yeah Proof
# Your Type (Tere Vargiyan) [feat. Mickey Singh] by Fateh
# 8 Parche (feat. Gur Sidhu) by Baani Sandhu
# Umbrella (feat. JAY-Z) by Rihanna
# Wanna Know by KR$NA
# You by Jassa Dhillon & Mxrci
# Vibez by ZAYN
# Vigdiyan Heeran by Yo Yo Honey Singh, Rony Ajnali & Gill Machhrai
# Winning Speech by Karan Aujla & MXRCI
# Lost by Tegi Pannu & Manni Sandhu
# Kina Chir by The PropheC
# Na Ja by Pav Dharia
# Mi Amor by Sharn, 40K & THE Paul
# Knightridah by Imran Khan
# LA Girls by Charlie Puth
# Let Me Be by Mickey Singh
# Lalkara (feat. Sultaan) by Diljit Dosanjh
# Jatt Vailly by Diljit Dosanjh
# Mamacita by Rarin
# Jind Mahi by Diljit Dosanjh
# Mahiya by Pav Dharia
# Jatta by Bunny Gill
# Let's Celebrate by Imran Khan & Sonakshi Sinha
# Mexico by Karan Aujla
# Kinni Kinni by Diljit Dosanjh
# Kiss Me Thru the Phone (feat. Sammie) by Soulja Boy Tell 'Em
# Move Your Body Now by Shaan, Hard Kaur, Suheil, Akriti Kakar & Pritam
# No Need by Karan Aujla
# Nadiyon Paar (Let the Music Play Again) by Sachin-Jigar, Rashmeet Kaur, Shamur & IP Singh
# Kya Baat Ay by Harrdy Sandhu
# MOVE TO MIAMI (feat. Pitbull) by Enrique Iglesias
# No Competition by Jass Manak
# Jawani by Arjan Dhillon
# Nasha by Pav Dharia
# She Move It Like by Badshah
# Ta Ta Ta (with Jason Derulo) by Bayanni & Jason Derulo
# Players (feat. Devika Badyal) by Badshah & Karan Aujla
# Sorry by Rajat Nagpal & Mickey Singh
# Notorious by Wazir Patar
# Rooftop Party (feat. Amar Sandhu) by Mickey Singh
# Rum Whisky by Akshay Verma
# Twist (Remix) by Neeraj Shridhar
# Samne Rehni E by Pav Dharia
# Stay Away by KR$NA & Bharg
# Slide (Remix) [feat. Pop Smoke, A Boogie wit da Hoodie & Chris Brown] by H.E.R.
# Some Of Us by KR$NA & AR Paisley
# Right Up There (feat. Lisa Mishra) by Badshah
# Switchin' Lanes by Tegi Pannu, Sukha & Manni Sandhu
# Ooo La La by Rozei
# Police by DJ Flow
# Te Amo by Kamal Raja & AyoB
# Thrift Shop (feat. Wanz) by Macklemore & Ryan Lewis
# Phone by Mickey Singh & UpsideDown
# Sift by Bhalwaan & Signature by SB
# Rain Over Me (feat. Marc Anthony) by Pitbull
# Straight Ballin' by DIVINE & Karan Aujla
# Rich Boy by payton

# %%
# Append the lyrics to the JSON file
with open('hindi_songs_with_lyrics.json', 'w', encoding='utf-8') as json_file:
    json.dump(selected_songs, json_file, ensure_ascii=False, indent=4)
